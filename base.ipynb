# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.style
import numpy as np
import util
matplotlib.style.use('ggplot')

# %%
WIDTH, HEIGHT = 20, 10
V_INF = 0.1

# %%
# Circle

R = 5
gamma = 0


def velocityCircle(z):
    return V_INF * (1 - (R / z) ** 2) - gamma / (2j * np.pi * z)


def maskCircle(z):
    return abs(z) < R


pictureCircle = plt.Circle((0, 0), R, color='g')

# %%
util.showStream(WIDTH, HEIGHT, velocityCircle, pictureCircle, maskCircle)

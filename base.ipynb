# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.style
matplotlib.style.use('ggplot')

# %%
from math import pi

width, height = 20, 20
r = 5
vinf = 5
gamma = 0

def velocity(z):
    return vinf * (1 - (r / z) ** 2) - gamma / (2j * pi * z)

# %%
x, y = range(-width, width + 1), range(-height, height + 1)

plt.figure(figsize=(20, 20))
plt.xlim(-width, width + 1, 0.25)
plt.ylim(-height, height + 1, 0.25)

for i in x:
    for j in y:
        if i * i + j * j > r * r:
            v = velocity(complex(i, j))
            plt.arrow(i, j, v.real, -v.imag, color='red', shape='full',
                      length_includes_head=True, head_width=0.2, head_length=0.4)
